# %%
import sys
# add didgelab source code to path
sys.path.append('../../')

import pickle
from cad.ui.visualization import DidgeVisualizer

# %%
data = pickle.load(open("../../../../evolutions/ericeira1/results/1.pkl", "rb"))
geos = [data.get(i).geo for i in range(10)]

geo = geos[0]
print(geo.get_cadsd().get_notes())
DidgeVisualizer.vis_didge(geo)
# Out:
#        freq     impedance   rel_imp  note-number  cent-diff note-name
# 1692   73.3  2.603310e+07  1.000000          -31   2.742104        D1
# 117   147.0  6.713927e+06  0.257900          -19  -1.975158        D2
# 223   253.0  3.513073e+06  0.134946          -10 -41.960633        B3
# 300   330.0  3.110543e+06  0.119484           -5  -1.955001        E3
# 410   440.0  2.540336e+06  0.097581            0   0.000000        A4
# 505   535.0  3.428270e+06  0.131689            3 -38.442441        C4
# 623   653.0  2.174634e+06  0.083533            7  16.504638        E4
# 725   755.0  2.028518e+06  0.077921            9 -34.767745       F#4
# 850   880.0  1.600548e+06  0.061481           12   0.000000        A5
# 955   985.0  1.733610e+06  0.066593           14   4.855759        B5
# <AxesSubplot: xlabel='x', ylabel='y'>

# %%
data.get(0).parameterset
# Out:
#                   name   value     min      max  mutable
# 0             l_gerade  803.27  500.00  1500.00    False
# 1             d_gerade    1.13    0.90     1.20    False
# 2   n_opening_segments    8.00    0.00     8.00    False
# 3     opening_factor_x    2.00   -2.00     2.00    False
# 4     opening_factor_y    0.72   -2.00     2.00    False
# 5       opening_length  898.95  700.00  1000.00    False
# 6           d_pre_bell   40.00   40.00    50.00    False
# 7               l_bell   21.46   20.00    50.00    False
# 8             bellsize    9.00    5.00    30.00    False
# 9         add_bubble_0    0.98    0.00     1.00    False
# 10     bubble_height_0    0.41    0.00     1.00    False
# 11        bubble_pos_0    0.88    0.00     1.00    False
# 12      bubble_width_0  127.45    0.00   300.00    False
